# %% [markdown]
# <a href="https://colab.research.google.com/github/Haniabuarab/AAU-Project/blob/main/LectureOneAAU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("marhaba")
# Out:
# marhaba
